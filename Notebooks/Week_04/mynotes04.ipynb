# %%
import pandas as pd #esto es para llamar a pandas como pd

# %%
url = "https://raw.githubusercontent.com/Pramirezortega/class_datascience/main/Notebooks/Week_04/data/GrDP_Panel-Data.csv"

df=pd.read_csv(url)

type(df) #lo importamos desde el github - vas al folder data= clicas al "raw"
# Out:
# pandas.core.frame.DataFrame

# %%
pwd
# Out:
# 'C:\\Users\\paula\\Desktop\\UNIL\\Statistics and Data Science\\GitHub\\class_datascience\\Notebooks\\Week_04'

# %%
df #esto es dataframe: to understand its structure and what it contains. In a notebook, we can directly look at it in a nice, visual way:
# Out:
#             Country  Year  GDP [million Euro]  Population  \
# 0           Belgium  1990                 NaN   9947782.0
# 1          Bulgaria  1990                 NaN   8767308.0
# 2           Czechia  1990                 NaN  10362102.0
# 3           Denmark  1990            108898.0   5135409.0
# 4           Germany  1990           1245386.0  62679035.0
# ..              ...   ...                 ...         ...
# 895         Finland  2019            239858.0   5517919.0
# 896          Sweden  2019            476869.5  10230185.0
# 897          Norway  2019            361734.6   5328212.0
# 898     Switzerland  2019            653732.6   8544527.0
# 899  United Kingdom  2019           2526615.2  66647112.0
#
#      Emissions_GHG [thousand tonnes CO2eq]  Emissions_NOx [tonne]  \
# 0                                142750.63                 428830
# 1                                 80468.09                 273150
# 2                                189911.77                 748990
# ...

# %%
df.head() #para ver solo la primeras lineas
# Out:
#     Country  Year  GDP [million Euro]  Population  \
# 0   Belgium  1990                 NaN   9947782.0
# 1  Bulgaria  1990                 NaN   8767308.0
# 2   Czechia  1990                 NaN  10362102.0
# 3   Denmark  1990            108898.0   5135409.0
# 4   Germany  1990           1245386.0  62679035.0
#
#    Emissions_GHG [thousand tonnes CO2eq]  Emissions_NOx [tonne]  \
# 0                              142750.63                 428830
# 1                               80468.09                 273150
# 2                              189911.77                 748990
# 3                               77995.13                 302240
# 4                             1268921.81                2850050
#
#    Emissions_PM2.5 [tonne]  Emissions_PM10 [tonne]  Emissions_SOx [tonne]  \
# 0                    49270                   67570                 364540
# 1                    22860                   42800                1105720
# ...

# %%
pwd
# Out:
# 'C:\\Users\\paula\\Desktop\\UNIL\\Statistics and Data Science\\GitHub\\class_datascience\\Notebooks\\Week_04'

# %%
len(df)
# Out:
# 900

# %%
len(df.columns)
# Out:
# 17

# %%
df.shape #para saber rows, columnas
# Out:
# (900, 17)

# %%
df.keys()
# Out:
# Index(['Country', 'Year', 'GDP [million Euro]', 'Population',
#        'Emissions_GHG [thousand tonnes CO2eq]', 'Emissions_NOx [tonne]',
#        'Emissions_PM2.5 [tonne]', 'Emissions_PM10 [tonne]',
#        'Emissions_SOx [tonne]', 'Emissions_NMVOC [tonne]',
#        'Emissions_NH3 [tonne]', 'Emissions_Pb [tonne]', 'Emissions_Cd [tonne]',
#        'Emissions_Hg [tonne]', 'Emissions_As [tonne]', 'Emissions_Ni [tonne]',
#        'Emissions_Cr [tonne]'],
#       dtype='object')

# %%
df['Population'] # We index data frames by columns. For instance, let's have a look at countries' population
# Out:
# 0       9947782.0
# 1       8767308.0
# 2      10362102.0
# 3       5135409.0
# 4      62679035.0
#           ...
# 895     5517919.0
# 896    10230185.0
# 897     5328212.0
# 898     8544527.0
# 899    66647112.0
# Name: Population, Length: 900, dtype: float64

# %%
#te crea directamente un index al importar (son los numeros de la izquierda)

# %%
df['Population'][0] #esto es del population column dame el que tiene el index 0
# Out:
# 9947782.0

# %%
df.loc[0, 'Population'] #the same que lo de arriba, pero se prefiere
# Out:
# 9947782.0

# %%
df.loc[[3,87], ['Country', 'Year','GDP [million Euro]','Population']] #esto es para verlo con más datos
# Out:
#     Country  Year  GDP [million Euro]  Population
# 3   Denmark  1990            108898.0   5135409.0
# 87   Norway  1992            101108.3   4273634.0

# %%
df.loc[0,:] #los dos puntos es para decir quiero el 0 entero
# Out:
# Country                                    Belgium
# Year                                          1990
# GDP [million Euro]                             NaN
# Population                               9947782.0
# Emissions_GHG [thousand tonnes CO2eq]    142750.63
# Emissions_NOx [tonne]                       428830
# Emissions_PM2.5 [tonne]                      49270
# Emissions_PM10 [tonne]                       67570
# Emissions_SOx [tonne]                       364540
# Emissions_NMVOC [tonne]                     348240
# Emissions_NH3 [tonne]                       129730
# Emissions_Pb [tonne]                           253
# Emissions_Cd [tonne]                             6
# Emissions_Hg [tonne]                             6
# Emissions_As [tonne]                             7
# Emissions_Ni [tonne]                            77
# Emissions_Cr [tonne]                            36
# Name: 0, dtype: object

# %%
df.loc[1:10:2, 'Country':'Population']
# Out:
#     Country  Year  GDP [million Euro]  Population
# 1  Bulgaria  1990                 NaN   8767308.0
# 3   Denmark  1990            108898.0   5135409.0
# 5   Estonia  1990                 NaN   1570599.0
# 7    Greece  1990                 NaN  10120892.0
# 9    France  1990            999521.7         NaN

# %%
df.iloc[1:10:2, 0:4] #te dice: rows de la 1-10 saltando 2, columnas de la 0 a la 4. OJO QUE ESTO ES Iloc (no loc)
# Out:
#     Country  Year  GDP [million Euro]  Population
# 1  Bulgaria  1990                 NaN   8767308.0
# 3   Denmark  1990            108898.0   5135409.0
# 5   Estonia  1990                 NaN   1570599.0
# 7    Greece  1990                 NaN  10120892.0
# 9    France  1990            999521.7         NaN

# %%
df.loc[0:1]
# Out:
#     Country  Year  GDP [million Euro]  Population  \
# 0   Belgium  1990                 NaN   9947782.0
# 1  Bulgaria  1990                 NaN   8767308.0
#
#    Emissions_GHG [thousand tonnes CO2eq]  Emissions_NOx [tonne]  \
# 0                              142750.63                 428830
# 1                               80468.09                 273150
#
#    Emissions_PM2.5 [tonne]  Emissions_PM10 [tonne]  Emissions_SOx [tonne]  \
# 0                    49270                   67570                 364540
# 1                    22860                   42800                1105720
#
#    Emissions_NMVOC [tonne]  Emissions_NH3 [tonne]  Emissions_Pb [tonne]  \
# 0                   348240                 129730                   253
# 1                   440600                 102130                   448
#
#    Emissions_Cd [tonne]  Emissions_Hg [tonne] Emissions_As [tonne]  \
# 0                     6                     6                    7
# ...

# %%
df.iloc[0:1]
# Out:
#    Country  Year  GDP [million Euro]  Population  \
# 0  Belgium  1990                 NaN   9947782.0
#
#    Emissions_GHG [thousand tonnes CO2eq]  Emissions_NOx [tonne]  \
# 0                              142750.63                 428830
#
#    Emissions_PM2.5 [tonne]  Emissions_PM10 [tonne]  Emissions_SOx [tonne]  \
# 0                    49270                   67570                 364540
#
#    Emissions_NMVOC [tonne]  Emissions_NH3 [tonne]  Emissions_Pb [tonne]  \
# 0                   348240                 129730                   253
#
#    Emissions_Cd [tonne]  Emissions_Hg [tonne] Emissions_As [tonne]  \
# 0                     6                     6                    7
#
#   Emissions_Ni [tonne] Emissions_Cr [tonne]
# 0                   77                   36

# %% [markdown]
# As a parenthesis, note that in our case, the label column is using integers - this is the default when importing data. Hence, extracting rows with `.loc` and `iloc` is using the same syntax... Almost:
# - `.loc` gets rows and columns with particular **labels** (in our case, integers)
# -`.iloc` gets rows and columns at integer **locations**
#
# How does it affect us? Well, one difference is slicing. While `.iloc` works the same as slicing lists, `.loc` is a little bit different. For example, if we pass as argument `[0:1]`, `.iloc` would only return the first row (as with lists, slicing excludes the last element), but `.loc` would return the two rows with labels 0 and 1:

# %%
df['Country'] == 'Switzerland'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 895    False
# 896    False
# 897    False
# 898     True
# 899    False
# Name: Country, Length: 900, dtype: bool

# %%
df[df['Country'] == 'Switzerland'] #te va a buscar todos los switzerland - esto es una condición
# Out:
#          Country  Year  GDP [million Euro]  Population  \
# 28   Switzerland  1990            209686.3   6673850.0
# 58   Switzerland  1991            217731.6   6757188.0
# 88   Switzerland  1992            216721.6   6842768.0
# 118  Switzerland  1993            232687.8   6907959.0
# 148  Switzerland  1994            254448.5   6968570.0
# 178  Switzerland  1995            270155.4   7019019.0
# 208  Switzerland  1996            268398.8   7062354.0
# 238  Switzerland  1997            260529.0   7081346.0
# 268  Switzerland  1998            271620.6   7096465.0
# 298  Switzerland  1999            280220.9   7123537.0
# 328  Switzerland  2000            303354.3   7164444.0
# 358  Switzerland  2001            320902.7   7204055.0
# 388  Switzerland  2002            329543.3   7255653.0
# 418  Switzerland  2003            321415.6   7313853.0
# 448  Switzerland  2004            326647.4   7364148.0
# 478  Switzerland  2005            338217.8   7415102.0
# ...

# %%
df[(df['Country'] == 'Switzerland') & (df['Year'] == 2019)] #2 condiciones ahora
# Out:
#          Country  Year  GDP [million Euro]  Population  \
# 898  Switzerland  2019            653732.6   8544527.0
#
#      Emissions_GHG [thousand tonnes CO2eq]  Emissions_NOx [tonne]  \
# 898                               43981.61                  61330
#
#      Emissions_PM2.5 [tonne]  Emissions_PM10 [tonne]  Emissions_SOx [tonne]  \
# 898                     6150                   14130                   4440
#
#      Emissions_NMVOC [tonne]  Emissions_NH3 [tonne]  Emissions_Pb [tonne]  \
# 898                    81150                  53800                    15
#
#      Emissions_Cd [tonne]  Emissions_Hg [tonne] Emissions_As [tonne]  \
# 898                     1                     1                    0
#
#     Emissions_Ni [tonne] Emissions_Cr [tonne]
# 898                    0                    0

# %%
df.dtypes #cosas raras en los últimos 3 xq tendrían q ser numeros y pone objects q son palabras
# Out:
# Country                                   object
# Year                                       int64
# GDP [million Euro]                       float64
# Population                               float64
# Emissions_GHG [thousand tonnes CO2eq]    float64
# Emissions_NOx [tonne]                      int64
# Emissions_PM2.5 [tonne]                    int64
# Emissions_PM10 [tonne]                     int64
# Emissions_SOx [tonne]                      int64
# Emissions_NMVOC [tonne]                    int64
# Emissions_NH3 [tonne]                      int64
# Emissions_Pb [tonne]                       int64
# Emissions_Cd [tonne]                       int64
# Emissions_Hg [tonne]                       int64
# Emissions_As [tonne]                      object
# Emissions_Ni [tonne]                      object
# Emissions_Cr [tonne]                      object
# dtype: object

# %% [markdown]
# You may wonder about the emissions of arsenic (As), nickel (Ni), and chromium (Cr), which are apparently `object` type. We will discover why later.

# %%
df['Country'].unique() #para ver todos los paises
# Out:
# array(['Belgium', 'Bulgaria', 'Czechia', 'Denmark', 'Germany', 'Estonia',
#        'Ireland', 'Greece', 'Spain', 'France', 'Croatia', 'Italy',
#        'Cyprus', 'Latvia', 'Lithuania', 'Luxembourg', 'Hungary', 'Malta',
#        'Netherlands', 'Austria', 'Poland', 'Portugal', 'Romania',
#        'Slovenia', 'Slovakia', 'Finland', 'Sweden', 'Norway',
#        'Switzerland', 'United Kingdom'], dtype=object)

# %%
df.Year.unique() #esto es lo mismo q lo de abajo, es otra forma de hacerlo
# Out:
# array([1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000,
#        2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#        2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019], dtype=int64)

# %%
df['Year'].unique()
# Out:
# array([1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000,
#        2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#        2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019], dtype=int64)

# %% [markdown]
# #### Identifying NaN #nan is NotaNumber

# %%
df.isna()
# Out:
#      Country   Year  GDP [million Euro]  Population  \
# 0      False  False                True       False
# 1      False  False                True       False
# 2      False  False                True       False
# 3      False  False               False       False
# 4      False  False               False       False
# ..       ...    ...                 ...         ...
# 895    False  False               False       False
# 896    False  False               False       False
# 897    False  False               False       False
# 898    False  False               False       False
# 899    False  False               False       False
#
#      Emissions_GHG [thousand tonnes CO2eq]  Emissions_NOx [tonne]  \
# 0                                    False                  False
# 1                                    False                  False
# 2                                    False                  False
# 3                                    False                  False
# ...

# %%
df.isna().sum()  #contar los numeros de NaNs por columna
# Out:
# Country                                    0
# Year                                       0
# GDP [million Euro]                       113
# Population                                 1
# Emissions_GHG [thousand tonnes CO2eq]      0
# Emissions_NOx [tonne]                      0
# Emissions_PM2.5 [tonne]                    0
# Emissions_PM10 [tonne]                     0
# Emissions_SOx [tonne]                      0
# Emissions_NMVOC [tonne]                    0
# Emissions_NH3 [tonne]                      0
# Emissions_Pb [tonne]                       0
# Emissions_Cd [tonne]                       0
# Emissions_Hg [tonne]                       0
# Emissions_As [tonne]                       0
# Emissions_Ni [tonne]                       0
# Emissions_Cr [tonne]                       0
# dtype: int64

# %%
df[(df['GDP [million Euro]'].isna()) | (df['Population'].isna())] #we will extract the rows where we can find NaN
# Out:
#       Country  Year  GDP [million Euro]  Population  \
# 0     Belgium  1990                 NaN   9947782.0
# 1    Bulgaria  1990                 NaN   8767308.0
# 2     Czechia  1990                 NaN  10362102.0
# 5     Estonia  1990                 NaN   1570599.0
# 6     Ireland  1990                 NaN   3506970.0
# ..        ...   ...                 ...         ...
# 140    Poland  1994                 NaN  38504707.0
# 141  Portugal  1994                 NaN   9974391.0
# 142   Romania  1994                 NaN  22748027.0
# 143  Slovenia  1994                 NaN   1989408.0
# 144  Slovakia  1994                 NaN   5336455.0
#
#      Emissions_GHG [thousand tonnes CO2eq]  Emissions_NOx [tonne]  \
# 0                                142750.63                 428830
# 1                                 80468.09                 273150
# 2                                189911.77                 748990
# 5                                 37015.28                  80050
# ...

# %%
df[(df['GDP [million Euro]'].isna()) | (df['Population'].isna())].Year.unique()
# Out:
# array([1990, 1991, 1992, 1993, 1994], dtype=int64)

# %% [markdown]
# #### Droping NaN

# %%
df_clean = df.dropna() 

df_clean
# Out:
#             Country  Year  GDP [million Euro]  Population  \
# 3           Denmark  1990            108898.0   5135409.0
# 4           Germany  1990           1245386.0  62679035.0
# 25          Finland  1990            111394.9   4974383.0
# 27           Norway  1990             94339.8   4233116.0
# 28      Switzerland  1990            209686.3   6673850.0
# ..              ...   ...                 ...         ...
# 895         Finland  2019            239858.0   5517919.0
# 896          Sweden  2019            476869.5  10230185.0
# 897          Norway  2019            361734.6   5328212.0
# 898     Switzerland  2019            653732.6   8544527.0
# 899  United Kingdom  2019           2526615.2  66647112.0
#
#      Emissions_GHG [thousand tonnes CO2eq]  Emissions_NOx [tonne]  \
# 3                                 77995.13                 302240
# 4                               1268921.81                2850050
# 25                                57740.85                 306350
# ...

# %%
df_clean.isna().sum().sum() #para ver si lo hemos hecho bien y vamos a buscar es si queda alguno
# Out:
# 0

# %%
df_clean = df_clean.drop(df_clean[df_clean.Year < 1995].index) #quitamos todos los datos anteriores a 1995

df_clean
# Out:
#             Country  Year  GDP [million Euro]  Population  \
# 150         Belgium  1995            220251.5  10130574.0
# 151        Bulgaria  1995             14512.8   8427418.0
# 152         Czechia  1995             46008.4  10333161.0
# 153         Denmark  1995            141441.4   5215718.0
# 154         Germany  1995           1977604.1  81538603.0
# ..              ...   ...                 ...         ...
# 895         Finland  2019            239858.0   5517919.0
# 896          Sweden  2019            476869.5  10230185.0
# 897          Norway  2019            361734.6   5328212.0
# 898     Switzerland  2019            653732.6   8544527.0
# 899  United Kingdom  2019           2526615.2  66647112.0
#
#      Emissions_GHG [thousand tonnes CO2eq]  Emissions_NOx [tonne]  \
# 150                              151311.86                 415990
# 151                               54038.12                 181900
# 152                              147738.40                 384910
# ...

# %%
df_clean.isna().sum().sum()
# Out:
# 0

# %% [markdown]
# #### Dealing with errors and other missing values

# %%
df_clean.loc[238, 'Emissions_As [tonne]']
# Out:
# 'Not Available'

# %%
(df_clean == 'Not Available').sum() #en que columna tenemos el Not Available
# Out:
# Country                                   0
# Year                                      0
# GDP [million Euro]                        0
# Population                                0
# Emissions_GHG [thousand tonnes CO2eq]     0
# Emissions_NOx [tonne]                     0
# Emissions_PM2.5 [tonne]                   0
# Emissions_PM10 [tonne]                    0
# Emissions_SOx [tonne]                     0
# Emissions_NMVOC [tonne]                   0
# Emissions_NH3 [tonne]                     0
# Emissions_Pb [tonne]                      0
# Emissions_Cd [tonne]                      0
# Emissions_Hg [tonne]                      0
# Emissions_As [tonne]                     10
# Emissions_Ni [tonne]                     10
# Emissions_Cr [tonne]                     10
# dtype: int64

# %%
df_clean[df_clean['Emissions_As [tonne]'] == 'Not Available']
# Out:
#          Country  Year  GDP [million Euro]  Population  \
# 165   Luxembourg  1995             15946.2    405650.0
# 178  Switzerland  1995            270155.4   7019019.0
# 195   Luxembourg  1996             16462.1    411600.0
# 208  Switzerland  1996            268398.8   7062354.0
# 225   Luxembourg  1997             17266.5    416850.0
# 238  Switzerland  1997            260529.0   7081346.0
# 255   Luxembourg  1998             18005.7    422050.0
# 268  Switzerland  1998            271620.6   7096465.0
# 285   Luxembourg  1999             20547.8    427350.0
# 298  Switzerland  1999            280220.9   7123537.0
#
#      Emissions_GHG [thousand tonnes CO2eq]  Emissions_NOx [tonne]  \
# 165                                9593.98                  34960
# 178                               48986.59                 115870
# 195                                9612.06                  35080
# 208                               48052.24                 110100
# ...

# %%
df_clean = df_clean.replace('Not Available', 0) 
#como seguramente no tendrán gran efecto ya que son lux y swiss, so asumimos q no tendrán muchas emisiones

df_clean
# Out:
#             Country  Year  GDP [million Euro]  Population  \
# 150         Belgium  1995            220251.5  10130574.0
# 151        Bulgaria  1995             14512.8   8427418.0
# 152         Czechia  1995             46008.4  10333161.0
# 153         Denmark  1995            141441.4   5215718.0
# 154         Germany  1995           1977604.1  81538603.0
# ..              ...   ...                 ...         ...
# 895         Finland  2019            239858.0   5517919.0
# 896          Sweden  2019            476869.5  10230185.0
# 897          Norway  2019            361734.6   5328212.0
# 898     Switzerland  2019            653732.6   8544527.0
# 899  United Kingdom  2019           2526615.2  66647112.0
#
#      Emissions_GHG [thousand tonnes CO2eq]  Emissions_NOx [tonne]  \
# 150                              151311.86                 415990
# 151                               54038.12                 181900
# 152                              147738.40                 384910
# ...

# %%
(df_clean == 'Not Available').sum().sum() #para ver q todo esté bien y q se hayan ido los Not Available
# Out:
# 0

# %% [markdown]
# We will modify the type of our columns. Indeed, the `object` type might be inconvenient when we will perform numerical operations. We will use the `to_numeric` pandas function and the `.apply()` method, which allows us to apply our function along one axis of our dataframe, in this case to each column.

# %%
list_hm_obj = ['Emissions_As [tonne]', 'Emissions_Ni [tonne]', 'Emissions_Cr [tonne]']

df_clean[list_hm_obj] = df_clean[list_hm_obj].apply(pd.to_numeric)

df_clean.dtypes
# Out:
# Country                                   object
# Year                                       int64
# GDP [million Euro]                       float64
# Population                               float64
# Emissions_GHG [thousand tonnes CO2eq]    float64
# Emissions_NOx [tonne]                      int64
# Emissions_PM2.5 [tonne]                    int64
# Emissions_PM10 [tonne]                     int64
# Emissions_SOx [tonne]                      int64
# Emissions_NMVOC [tonne]                    int64
# Emissions_NH3 [tonne]                      int64
# Emissions_Pb [tonne]                       int64
# Emissions_Cd [tonne]                       int64
# Emissions_Hg [tonne]                       int64
# Emissions_As [tonne]                       int64
# Emissions_Ni [tonne]                       int64
# Emissions_Cr [tonne]                       int64
# dtype: object

# %% [markdown]
# We will reset the labels of our rows - as you can see above, the rows numbers were the ones from our original data frame. We can simply do that using the method `.reset_index`. The argument `drop=True` drops the previous labels, while `drop=False` (default value) will insert the previous labels in a new column.

# %%
df_clean = df_clean.reset_index(drop=True)
df_clean
# Out:
#             Country  Year  GDP [million Euro]  Population  \
# 0           Belgium  1995            220251.5  10130574.0
# 1          Bulgaria  1995             14512.8   8427418.0
# 2           Czechia  1995             46008.4  10333161.0
# 3           Denmark  1995            141441.4   5215718.0
# 4           Germany  1995           1977604.1  81538603.0
# ..              ...   ...                 ...         ...
# 745         Finland  2019            239858.0   5517919.0
# 746          Sweden  2019            476869.5  10230185.0
# 747          Norway  2019            361734.6   5328212.0
# 748     Switzerland  2019            653732.6   8544527.0
# 749  United Kingdom  2019           2526615.2  66647112.0
#
#      Emissions_GHG [thousand tonnes CO2eq]  Emissions_NOx [tonne]  \
# 0                                151311.86                 415990
# 1                                 54038.12                 181900
# 2                                147738.40                 384910
# ...
